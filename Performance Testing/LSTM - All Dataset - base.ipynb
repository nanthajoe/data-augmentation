# %% [markdown]
# # Data Preparation

# %%
import pandas as pd
import tensorflow as tf
import numpy as np

import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
datasetPath = "/content/drive/MyDrive/Thesis/Code/GenerativeDataAugmentation/Coba18 - Testing All Dataset/dataset.csv"
dataset = pd.read_csv(datasetPath, index_col=0, encoding="utf-8")
dataset
# Out:
#                                                     Text   Emotion
# 0             Thanks! I'm glad you got a kick out of it.       joy
# 1      I'm more surprised the dash cam was functionin...  surprise
# 2      i dont know how i feel about my beloved teams ...      love
# 3      when i learnt that my best friend had failed t...     anger
# 4      i feel as though that talking for a month is a...       joy
# ...                                                  ...       ...
# 65023                             I love truck drivers!!      love
# 65024  I knew I'd see him here eventually. I really l...       joy
# 65025                              Nope what’s it about?  surprise
# 65026                             Removed and warned. R1     anger
# 65027  i want to be irreplaceable and until i find th...     anger
#
# [65028 rows x 2 columns]

# %%
dataset.rename(columns={'text' : 'Text', 'emotion' : 'Emotion'}, inplace=True)

# %%
dataset
# Out:
#                                                     Text   Emotion
# 0             Thanks! I'm glad you got a kick out of it.       joy
# 1      I'm more surprised the dash cam was functionin...  surprise
# 2      i dont know how i feel about my beloved teams ...      love
# 3      when i learnt that my best friend had failed t...     anger
# 4      i feel as though that talking for a month is a...       joy
# ...                                                  ...       ...
# 65023                             I love truck drivers!!      love
# 65024  I knew I'd see him here eventually. I really l...       joy
# 65025                              Nope what’s it about?  surprise
# 65026                             Removed and warned. R1     anger
# 65027  i want to be irreplaceable and until i find th...     anger
#
# [65028 rows x 2 columns]

# %%
dataset = dataset[dataset.Emotion != 'love']

# %%
dataset['Emotion'].value_counts().sort_index()
# Out:
# anger       10793
# disgust      5301
# fear         5570
# joy         14744
# sadness     12555
# surprise     6233
# Name: Emotion, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

dataset['emotion_encode'] = le.fit_transform(dataset['Emotion'])
dataset.head()
# Out:
# <ipython-input-7-f27a98eed3b1>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['emotion_encode'] = le.fit_transform(dataset['Emotion'])
#                                                 Text   Emotion  emotion_encode
# 0         Thanks! I'm glad you got a kick out of it.       joy               3
# 1  I'm more surprised the dash cam was functionin...  surprise               5
# 3  when i learnt that my best friend had failed t...     anger               0
# 4  i feel as though that talking for a month is a...       joy               3
# 5  i feel like the addition of sweet fresh corn r...       joy               3

# %%
le_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
print(le_mapping)
# Out:
# {'anger': 0, 'disgust': 1, 'fear': 2, 'joy': 3, 'sadness': 4, 'surprise': 5}

# %%
LABEL_NAME = le.classes_
print(LABEL_NAME)
# Out:
# ['anger' 'disgust' 'fear' 'joy' 'sadness' 'surprise']

# %%
emotion_col = dataset.pop("Emotion")
emotion_col
# Out:
# 0             joy
# 1        surprise
# 3           anger
# 4             joy
# 5             joy
#            ...
# 65022       anger
# 65024         joy
# 65025    surprise
# 65026       anger
# 65027       anger
# Name: Emotion, Length: 55196, dtype: object

# %%
training_data, validation_data, test_data = np.split(dataset.sample(frac=1), [int(.8*len(dataset)), int(.9*len(dataset))])

# %%
print(training_data.shape)
print(validation_data.shape)
print(test_data.shape)
# Out:
# (44156, 2)
# (5520, 2)
# (5520, 2)

# %% [markdown]
# # One-hot Vector

# %%
trainX = np.array(training_data.iloc[:, 0])
trainY = np.array(training_data.iloc[:, 1])

testX = np.array(test_data.iloc[:, 0])
testY = np.array(test_data.iloc[:, 1])

valX = np.array(validation_data.iloc[:, 0])
valY = np.array(validation_data.iloc[:, 1])

# %%
trainY = pd.get_dummies(trainY).values
testY = pd.get_dummies(testY).values
valY = pd.get_dummies(valY).values

# %%
print(trainY.shape)
print(testY.shape)
print(valY.shape)
# Out:
# (44156, 6)
# (5520, 6)
# (5520, 6)

# %%
vocab_size = 5000
embedding_dim = 64
max_length = 80
oov_tok = '<OOV>'
trunc_type = 'pre'
padding_type = 'pre'

# %% [markdown]
# # Tokenizing, Sequencing, Padding

# %%
#Tokenize
tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(trainX)

tokenizer.word_index[''] = 0
tokenizer.index_word[0] = ''

word_index = tokenizer.word_index

# %%
len(word_index)
# Out:
# 24575

# %%
vocab_size = len(tokenizer.word_index)
vocab_size
# Out:
# 24575

# %%
#Sequencing
train_seqs = tokenizer.texts_to_sequences(trainX)
val_seqs = tokenizer.texts_to_sequences(valX)
test_seqs = tokenizer.texts_to_sequences(testX)

# %%
#Padding
train_seqs = pad_sequences(train_seqs, maxlen=max_length, padding=padding_type, truncating=trunc_type)
val_seqs = pad_sequences(val_seqs, maxlen=max_length, padding=padding_type, truncating=trunc_type)
test_seqs = pad_sequences(test_seqs, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# %% [markdown]
# # Model Training

# %%
model = tf.keras.Sequential([
    # Add an Embedding layer expecting input vocab of size 5000, and output embedding dimension of size 64 we set at the top
    tf.keras.layers.Embedding(vocab_size, embedding_dim),
    tf.keras.layers.LSTM(embedding_dim),
#    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    # use ReLU in place of tanh function since they are very good alternatives of each other.
    tf.keras.layers.Dense(embedding_dim, activation='relu'),
    # Add a Dense layer with 6 units and softmax activation.
    # When we have multiple outputs, softmax convert outputs layers into a probability distribution.
    tf.keras.layers.Dense(6, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 64)          1572800
#
#  lstm (LSTM)                 (None, 64)                33024
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 6)                 390
#
# =================================================================
# Total params: 1,610,374
# Trainable params: 1,610,374
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
num_epochs = 10

# %%
# %%time
history = model.fit(train_seqs, trainY, epochs=num_epochs, validation_data=(val_seqs, valY), verbose=1)
# Out:
# Epoch 1/10
# 1380/1380 [==============================] - 34s 19ms/step - loss: 1.1193 - accuracy: 0.5842 - val_loss: 0.8308 - val_accuracy: 0.7111
# Epoch 2/10
# 1380/1380 [==============================] - 10s 8ms/step - loss: 0.7396 - accuracy: 0.7412 - val_loss: 0.7649 - val_accuracy: 0.7239
# Epoch 3/10
# 1380/1380 [==============================] - 10s 7ms/step - loss: 0.6537 - accuracy: 0.7642 - val_loss: 0.7697 - val_accuracy: 0.7346
# Epoch 4/10
# 1380/1380 [==============================] - 10s 7ms/step - loss: 0.5959 - accuracy: 0.7837 - val_loss: 0.7830 - val_accuracy: 0.7274
# Epoch 5/10
# 1380/1380 [==============================] - 9s 6ms/step - loss: 0.5502 - accuracy: 0.7987 - val_loss: 0.7839 - val_accuracy: 0.7333
# Epoch 6/10
# 1380/1380 [==============================] - 9s 6ms/step - loss: 0.5064 - accuracy: 0.8110 - val_loss: 0.8094 - val_accuracy: 0.7319
# Epoch 7/10
# 1380/1380 [==============================] - 9s 7ms/step - loss: 0.4717 - accuracy: 0.8214 - val_loss: 0.8663 - val_accuracy: 0.7257
# Epoch 8/10
# 1380/1380 [==============================] - 9s 7ms/step - loss: 0.4378 - accuracy: 0.8314 - val_loss: 0.9210 - val_accuracy: 0.7255
# Epoch 9/10
# 1380/1380 [==============================] - 9s 6ms/step - loss: 0.4142 - accuracy: 0.8385 - val_loss: 0.9617 - val_accuracy: 0.7174
# Epoch 10/10
# 1380/1380 [==============================] - 9s 6ms/step - loss: 0.3837 - accuracy: 0.8459 - val_loss: 1.0680 - val_accuracy: 0.7132
# CPU times: user 2min 18s, sys: 15 s, total: 2min 33s
# Wall time: 1min 57s

# %% [markdown]
# # Evaluation

# %%
def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

# %%
plot_graphs(history, 'accuracy')
plot_graphs(history, 'loss')

# %%
print('\nEpoch No.  Train Accuracy  Train Loss      Val Accuracy    Val Loss')
for i in range(num_epochs):
  print('{:8d} {:10f} \t {:10f} \t {:10f} \t {:10f}'.format(i + 1, history.history['accuracy'][i], history.history['loss'][i], history.history['val_accuracy'][i], history.history['val_loss'][i]))
# Out:
# Epoch No.  Train Accuracy  Train Loss      Val Accuracy    Val Loss
#        1   0.584224 	   1.119259 	   0.711051 	   0.830819
#        2   0.741213 	   0.739575 	   0.723913 	   0.764923
#        3   0.764177 	   0.653717 	   0.734601 	   0.769659
#        4   0.783699 	   0.595918 	   0.727355 	   0.783006
#        5   0.798714 	   0.550201 	   0.733333 	   0.783937
#        6   0.810988 	   0.506404 	   0.731884 	   0.809402
#        7   0.821383 	   0.471682 	   0.725725 	   0.866269
#        8   0.831416 	   0.437785 	   0.725543 	   0.920980
#        9   0.838504 	   0.414249 	   0.717391 	   0.961741
#       10   0.845865 	   0.383653 	   0.713225 	   1.068035

# %%
y_pred = np.argmax(model.predict(test_seqs), axis=1)
y_true = np.argmax(testY, axis=1)

loss, accuracy = model.evaluate(test_seqs, testY)
# Out:
# 173/173 [==============================] - 1s 2ms/step
# 173/173 [==============================] - 1s 3ms/step - loss: 1.0165 - accuracy: 0.7274

# %%
print(classification_report(y_pred, y_true))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.69      0.68      1077
#            1       0.42      0.43      0.43       524
#            2       0.73      0.65      0.69       600
#            3       0.88      0.85      0.86      1527
#            4       0.80      0.78      0.79      1295
#            5       0.58      0.71      0.64       497
#
#     accuracy                           0.73      5520
#    macro avg       0.68      0.68      0.68      5520
# weighted avg       0.73      0.73      0.73      5520
